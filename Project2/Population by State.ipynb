# %% [markdown]
# This notebook takes census data from the web and converts it into a pandas dataframe that we will merge with another dataframe on school shotting data.  We wanted to have this data to compair the number of shootings per capita by state to gun control laws to see if there is a corrilation between stronger gun control and less school shootings, or if can just be explained by the population of each state.

# %%
import pandas as pd

# %%
df1 = pd.read_excel('nst-est2017-01.xlsx')
#the data came from the folowing website: which no longer exsists so we had to use web archive to find it
#https://www.census.gov/data/datasets/2017/demo/popest/state-total.html
#https://web.archive.org/web/20180820005818/https://www2.census.gov/programs-surveys/popest/tables/2010-2017/state/totals/nst-est2017-01.xlsx

# %%
df1.head()
# Out:
#   table with row headers in column A and column headers in rows 3 through 4. (leading dots indicate sub-parts)  \
# 0  Table 1. Annual Estimates of the Resident Popu...
# 1                                    Geographic Area
# 2                                                NaN
# 3                                      United States
# 4                                          Northeast
#
#             Unnamed: 1      Unnamed: 2                          Unnamed: 3  \
# 0                  NaN             NaN                                 NaN
# 1  2010-04-01 00:00:00             NaN  Population Estimate (as of July 1)
# 2               Census  Estimates Base                                2010
# 3            308745538       308758105                           309338421
# 4             55317240        55318350                            55388349
#
#     Unnamed: 4   Unnamed: 5   Unnamed: 6   Unnamed: 7   Unnamed: 8  \
# ...

# %%
df1.columns = df1.iloc[2]

# %%
df1.head()
# Out:
# 2                                                NaN               Census  \
# 0  Table 1. Annual Estimates of the Resident Popu...                  NaN
# 1                                    Geographic Area  2010-04-01 00:00:00
# 2                                                NaN               Census
# 3                                      United States            308745538
# 4                                          Northeast             55317240
#
# 2  Estimates Base                                2010       2011.0  \
# 0             NaN                                 NaN          NaN
# 1             NaN  Population Estimate (as of July 1)          NaN
# 2  Estimates Base                                2010       2011.0
# 3       308758105                           309338421  311644280.0
# 4        55318350                            55388349   55642659.0
#
# 2       2012.0       2013.0       2014.0       2015.0       2016.0  \
# ...

# %%
df1 = df1.drop([0])

# %%
df1.head()
# Out:
# 2              NaN               Census  Estimates Base  \
# 1  Geographic Area  2010-04-01 00:00:00             NaN
# 2              NaN               Census  Estimates Base
# 3    United States            308745538       308758105
# 4        Northeast             55317240        55318350
# 5          Midwest             66927001        66929794
#
# 2                                2010       2011.0       2012.0       2013.0  \
# 1  Population Estimate (as of July 1)          NaN          NaN          NaN
# 2                                2010       2011.0       2012.0       2013.0
# 3                           309338421  311644280.0  313993272.0  316234505.0
# 4                            55388349   55642659.0   55860261.0   56047732.0
# 5                            66973360   67141501.0   67318295.0   67534451.0
#
# 2       2014.0       2015.0       2016.0       2017.0
# 1          NaN          NaN          NaN          NaN
# 2       2014.0       2015.0       2016.0       2017.0
# ...

# %%
df1 = df1.drop([1])

# %%
df1.head()
# Out:
# 2            NaN     Census  Estimates Base       2010       2011.0  \
# 2            NaN     Census  Estimates Base       2010       2011.0
# 3  United States  308745538       308758105  309338421  311644280.0
# 4      Northeast   55317240        55318350   55388349   55642659.0
# 5        Midwest   66927001        66929794   66973360   67141501.0
# 6          South  114555744       114563024  114869241  116060993.0
#
# 2       2012.0       2013.0       2014.0       2015.0       2016.0  \
# 2       2012.0       2013.0       2014.0       2015.0       2016.0
# 3  313993272.0  316234505.0  318622525.0  321039839.0  323405935.0
# 4   55860261.0   56047732.0   56203078.0   56296628.0   56359360.0
# 5   67318295.0   67534451.0   67720120.0   67839187.0   67978168.0
# 6  117291728.0  118422269.0  119699966.0  121081238.0  122423457.0
#
# 2       2017.0
# 2       2017.0
# 3  325719178.0
# 4   56470581.0
# 5   68179351.0
# 6  123658624.0

# %%
df1 = df1.drop([2,4,5,6,7])

# %%
df1.head()
# Out:
# 2             NaN     Census Estimates Base       2010       2011.0  \
# 3   United States  308745538      308758105  309338421  311644280.0
# 8        .Alabama    4779736        4780135    4785579    4798649.0
# 9         .Alaska     710231         710249     714015     722259.0
# 10       .Arizona    6392017        6392309    6407002    6465488.0
# 11      .Arkansas    2915918        2916031    2921737    2938640.0
#
# 2        2012.0       2013.0       2014.0       2015.0       2016.0  \
# 3   313993272.0  316234505.0  318622525.0  321039839.0  323405935.0
# 8     4813946.0    4827660.0    4840037.0    4850858.0    4860545.0
# 9      730825.0     736760.0     736759.0     737979.0     741522.0
# 10    6544211.0    6616124.0    6706435.0    6802262.0    6908642.0
# 11    2949208.0    2956780.0    2964800.0    2975626.0    2988231.0
#
# 2        2017.0
# 3   325719178.0
# 8     4874747.0
# 9      739795.0
# 10    7016270.0
# 11    3004279.0

# %%
df1 = df1.drop([59,60,61,62,63,64,65])

# %%
df1.head()
# Out:
# 2             NaN     Census Estimates Base       2010       2011.0  \
# 3   United States  308745538      308758105  309338421  311644280.0
# 8        .Alabama    4779736        4780135    4785579    4798649.0
# 9         .Alaska     710231         710249     714015     722259.0
# 10       .Arizona    6392017        6392309    6407002    6465488.0
# 11      .Arkansas    2915918        2916031    2921737    2938640.0
#
# 2        2012.0       2013.0       2014.0       2015.0       2016.0  \
# 3   313993272.0  316234505.0  318622525.0  321039839.0  323405935.0
# 8     4813946.0    4827660.0    4840037.0    4850858.0    4860545.0
# 9      730825.0     736760.0     736759.0     737979.0     741522.0
# 10    6544211.0    6616124.0    6706435.0    6802262.0    6908642.0
# 11    2949208.0    2956780.0    2964800.0    2975626.0    2988231.0
#
# 2        2017.0
# 3   325719178.0
# 8     4874747.0
# 9      739795.0
# 10    7016270.0
# 11    3004279.0

# %%
df1 = df1.rename(columns={            2011.0: 2011,           2012.0: 2012,           2013.0:2013,           2014.0: 2014,           2015.0:2015,           2016.0:2016,           2017.0:2017})

# %%
df1.columns
# Out:
# Index([nan, 'Census', 'Estimates Base', 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017],
#       dtype='object', name=2)

# %%
#df1 = df1.rename(columns={nan: "State"})

# %%
df1.iloc[:, 0]
# Out:
# 3             United States
# 8                  .Alabama
# 9                   .Alaska
# 10                 .Arizona
# 11                .Arkansas
# 12              .California
# 13                .Colorado
# 14             .Connecticut
# 15                .Delaware
# 16    .District of Columbia
# 17                 .Florida
# 18                 .Georgia
# 19                  .Hawaii
# 20                   .Idaho
# 21                .Illinois
# 22                 .Indiana
# 23                    .Iowa
# 24                  .Kansas
# 25                .Kentucky
# 26               .Louisiana
# 27                   .Maine
# 28                .Maryland
# 29           .Massachusetts
# 30                .Michigan
# 31               .Minnesota
# 32             .Mississippi
# 33                .Missouri
# 34                 .Montana
# 35                .Nebraska
# 36                  .Nevada
# 37           .New Hampshire
# 38              .New Jersey
# 39              .New Mexico
# ...

# %%
df1["State"] = [' United States','Alabama','Alaska','Arizona','Arkansas','California','Colorado','Connecticut','Delaware','District of Columbia','Florida','Georgia','Hawaii','Idaho','Illinois','Indiana','Iowa','Kansas','Kentucky','Louisiana','Maine','Maryland','Massachusetts','Michigan','Minnesota','Mississippi','Missouri','Montana','Nebraska','Nevada','New Hampshire','New Jersey','New Mexico','New York','North Carolina','North Dakota','Ohio','Oklahoma','Oregon','Pennsylvania','Rhode Island','South Carolina','South Dakota','Tennessee','Texas','Utah','Vermont','Virginia','Washington','West Virginia','Wisconsin','Wyoming']

# %%
df1.head()
# Out:
# 3   United States  308745538  308758105  309338421  311644280.0  313993272.0  \
# 3   United States  308745538  308758105  309338421  311644280.0  313993272.0
# 8        .Alabama    4779736    4780135    4785579    4798649.0    4813946.0
# 9         .Alaska     710231     710249     714015     722259.0     730825.0
# 10       .Arizona    6392017    6392309    6407002    6465488.0    6544211.0
# 11      .Arkansas    2915918    2916031    2921737    2938640.0    2949208.0
#
# 3   316234505.0  318622525.0  321039839.0  323405935.0  325719178.0  \
# 3   316234505.0  318622525.0  321039839.0  323405935.0  325719178.0
# 8     4827660.0    4840037.0    4850858.0    4860545.0    4874747.0
# 9      736760.0     736759.0     737979.0     741522.0     739795.0
# 10    6616124.0    6706435.0    6802262.0    6908642.0    7016270.0
# 11    2956780.0    2964800.0    2975626.0    2988231.0    3004279.0
#
# 3    United States
# 3    United States
# 8          Alabama
# 9           Alaska
# ...

# %%
df = df1.drop(df1.columns[0], axis=1)

# %%
df = df.drop(columns=['Census', 'Estimates Base'])

# %%
df.head()
# Out:
# 2        2010         2011         2012         2013         2014  \
# 3   309338421  311644280.0  313993272.0  316234505.0  318622525.0
# 8     4785579    4798649.0    4813946.0    4827660.0    4840037.0
# 9      714015     722259.0     730825.0     736760.0     736759.0
# 10    6407002    6465488.0    6544211.0    6616124.0    6706435.0
# 11    2921737    2938640.0    2949208.0    2956780.0    2964800.0
#
# 2          2015         2016         2017           State
# 3   321039839.0  323405935.0  325719178.0   United States
# 8     4850858.0    4860545.0    4874747.0         Alabama
# 9      737979.0     741522.0     739795.0          Alaska
# 10    6802262.0    6908642.0    7016270.0         Arizona
# 11    2975626.0    2988231.0    3004279.0        Arkansas

# %%
df2018 = pd.read_csv('Population Estimates by State.csv')
#this data is only the 2018 population by state from the census

# %%
df2018.head()
# Out:
# 0     State        2018
# 0    States  Population
# 1   Alabama   4,887,871
# 2    Alaska     737,438
# 3   Arizona   7,171,646
# 4  Arkansas   3,013,825

# %%
df2018 = df2018.rename(columns={'Population Estimates by State': "State"})

# %%
df2018.head()
# Out:
#       State  Unnamed: 1
# 0    States  Population
# 1   Alabama   4,887,871
# 2    Alaska     737,438
# 3   Arizona   7,171,646
# 4  Arkansas   3,013,825

# %%
df2018.columns = df2018.iloc[0]

# %%
df2018.head()
# Out:
# 0    States  Population
# 0    States  Population
# 1   Alabama   4,887,871
# 2    Alaska     737,438
# 3   Arizona   7,171,646
# 4  Arkansas   3,013,825

# %%
df2018 = df2018.rename(columns={'States': "State", 'Population':2018})

# %%
df2018.head()
# Out:
# 0     State        2018
# 0    States  Population
# 1   Alabama   4,887,871
# 2    Alaska     737,438
# 3   Arizona   7,171,646
# 4  Arkansas   3,013,825

# %%
result = pd.merge(df, df2018, how='left', on=['State'])

# %%
result.head()
# Out:
#         2010       2011         2012         2013         2014         2015  \
# 0  309338421  311644280  313993272.0  316234505.0  318622525.0  321039839.0
# 1    4785579    4798649    4813946.0    4827660.0    4840037.0    4850858.0
# 2     714015     722259     730825.0     736760.0     736759.0     737979.0
# 3    6407002    6465488    6544211.0    6616124.0    6706435.0    6802262.0
# 4    2921737    2938640    2949208.0    2956780.0    2964800.0    2975626.0
#
#           2016         2017           State       2018
# 0  323405935.0  325719178.0   United States        NaN
# 1    4860545.0    4874747.0         Alabama  4,887,871
# 2     741522.0     739795.0          Alaska    737,438
# 3    6908642.0    7016270.0         Arizona  7,171,646
# 4    2988231.0    3004279.0        Arkansas  3,013,825

# %%
#get rid of the floats and turn data into ints
result[2011] = result[2011].apply(lambda x: int(x))

# %%
result.head()
# Out:
#         2010       2011         2012         2013         2014         2015  \
# 0  309338421  311644280  313993272.0  316234505.0  318622525.0  321039839.0
# 1    4785579    4798649    4813946.0    4827660.0    4840037.0    4850858.0
# 2     714015     722259     730825.0     736760.0     736759.0     737979.0
# 3    6407002    6465488    6544211.0    6616124.0    6706435.0    6802262.0
# 4    2921737    2938640    2949208.0    2956780.0    2964800.0    2975626.0
#
#           2016         2017           State       2018
# 0  323405935.0  325719178.0   United States        NaN
# 1    4860545.0    4874747.0         Alabama  4,887,871
# 2     741522.0     739795.0          Alaska    737,438
# 3    6908642.0    7016270.0         Arizona  7,171,646
# 4    2988231.0    3004279.0        Arkansas  3,013,825

# %%
#yes, I know this isn't DRY code. So sue me, I was being lazy
result[2012] = result[2012].apply(lambda x: int(x))
result[2013] = result[2013].apply(lambda x: int(x))
result[2014] = result[2014].apply(lambda x: int(x))
result[2015] = result[2015].apply(lambda x: int(x))
result[2016] = result[2016].apply(lambda x: int(x))
result[2017] = result[2017].apply(lambda x: int(x))

# %%
result.head()
# Out:
#        2010      2011      2012      2013      2014      2015      2016  \
# 1   4785579   4798649   4813946   4827660   4840037   4850858   4860545
# 2    714015    722259    730825    736760    736759    737979    741522
# 3   6407002   6465488   6544211   6616124   6706435   6802262   6908642
# 4   2921737   2938640   2949208   2956780   2964800   2975626   2988231
# 5  37327690  37672654  38019006  38347383  38701278  39032444  39296476
#
#        2017        2018 State
# 1   4874747   4,887,871    AL
# 2    739795     737,438    AK
# 3   7016270   7,171,646    AZ
# 4   3004279   3,013,825    AR
# 5  39536653  39,557,045    CA

# %%
#our other data uses state abbrivations instead of the full names, so in order to join that data we added in the state codes
result["Code"] = ['US','AL','AK','AZ','AR','CA','CO','CT','DE','DC','FL','GA','HI','ID','IL','IN','IA','KS','KY','LA','ME','MD','MA','MI','MN','MS','MO','MT','NE','NV','NH','NJ','NM','NY','NC','ND','OH','OK','OR','PA','RI','SC','SD','TN','TX','UT','VT','VA','WA','WV','WI','WY']

# %%
result
# Out:
#          2010       2011       2012       2013       2014       2015  \
# 0   309338421  311644280  313993272  316234505  318622525  321039839
# 1     4785579    4798649    4813946    4827660    4840037    4850858
# 2      714015     722259     730825     736760     736759     737979
# 3     6407002    6465488    6544211    6616124    6706435    6802262
# 4     2921737    2938640    2949208    2956780    2964800    2975626
# 5    37327690   37672654   38019006   38347383   38701278   39032444
# 6     5048029    5116411    5186330    5262556    5342311    5440445
# 7     3580171    3591927    3597705    3602470    3600188    3593862
# 8      899712     907884     916868     925114     934805     944107
# 9      605040     620336     635630     650114     660797     672736
# 10   18846461   19097369   19341327   19584927   19897747   20268567
# 11    9712696    9810595    9911171    9981773   10083850   10199533
# 12    1363817    1378323    1392772    1408038    1417710    1426320
# ...

# %%
result = result.drop(columns=['State'])

# %%
result
# Out:
#          2010       2011       2012       2013       2014       2015  \
# 0   309338421  311644280  313993272  316234505  318622525  321039839
# 1     4785579    4798649    4813946    4827660    4840037    4850858
# 2      714015     722259     730825     736760     736759     737979
# 3     6407002    6465488    6544211    6616124    6706435    6802262
# 4     2921737    2938640    2949208    2956780    2964800    2975626
# 5    37327690   37672654   38019006   38347383   38701278   39032444
# 6     5048029    5116411    5186330    5262556    5342311    5440445
# 7     3580171    3591927    3597705    3602470    3600188    3593862
# 8      899712     907884     916868     925114     934805     944107
# 9      605040     620336     635630     650114     660797     672736
# 10   18846461   19097369   19341327   19584927   19897747   20268567
# 11    9712696    9810595    9911171    9981773   10083850   10199533
# 12    1363817    1378323    1392772    1408038    1417710    1426320
# ...

# %%
result = result.drop([0])

# %%
result
# Out:
#         2010      2011      2012      2013      2014      2015      2016  \
# 1    4785579   4798649   4813946   4827660   4840037   4850858   4860545
# 2     714015    722259    730825    736760    736759    737979    741522
# 3    6407002   6465488   6544211   6616124   6706435   6802262   6908642
# 4    2921737   2938640   2949208   2956780   2964800   2975626   2988231
# 5   37327690  37672654  38019006  38347383  38701278  39032444  39296476
# 6    5048029   5116411   5186330   5262556   5342311   5440445   5530105
# 7    3580171   3591927   3597705   3602470   3600188   3593862   3587685
# 8     899712    907884    916868    925114    934805    944107    952698
# 9     605040    620336    635630    650114    660797    672736    684336
# 10  18846461  19097369  19341327  19584927  19897747  20268567  20656589
# 11   9712696   9810595   9911171   9981773  10083850  10199533  10313620
# 12   1363817   1378323   1392772   1408038   1417710   1426320   1428683
# ...

# %%
#changing the name to make the join easier
result = result.rename(columns={'Code': "State"})

# %%
result.head()
# Out:
#        2010      2011      2012      2013      2014      2015      2016  \
# 1   4785579   4798649   4813946   4827660   4840037   4850858   4860545
# 2    714015    722259    730825    736760    736759    737979    741522
# 3   6407002   6465488   6544211   6616124   6706435   6802262   6908642
# 4   2921737   2938640   2949208   2956780   2964800   2975626   2988231
# 5  37327690  37672654  38019006  38347383  38701278  39032444  39296476
#
#        2017        2018 State
# 1   4874747   4,887,871    AL
# 2    739795     737,438    AK
# 3   7016270   7,171,646    AZ
# 4   3004279   3,013,825    AR
# 5  39536653  39,557,045    CA

# %%
result.to_csv('population.csv')
